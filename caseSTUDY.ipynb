# %%
#Import các thư viện cần thiết
import tkinter
from tkinter import *
from tkinter import ttk
from tkinter import font
from tkinter import messagebox
import json

# %%
#Log-in screen
 
root = Tk()
root.title('Piano Sales Management System')
root.geometry('450x200')
root.resizable(False, False)


def login():
    if (username_entry.get() == data['user']) & (password_entry.get() == data['password']):
	    root.destroy()
    else:
        messagebox.showerror(title='Sai thông tin đăng nhập', 
                             message='Vui lòng kiểm tra lại username và password')
          
# Labels and entries for username and password
username_label = Label(root, text='Username', font=('Andalus', 15, 'bold'), fg='brown')
password_label = Label(root, text='Password', font=('Andalus', 15, 'bold'),fg='brown')

username_entry_var = StringVar()
password_entry_var = StringVar()

username_entry = Entry(root, textvariable=username_entry_var, 
                                font=('Andalus', 15))
password_entry = Entry(root, textvariable=password_entry_var, show='*', 
                                        font=('Andalus', 15))
btn_login = Button(root, text='LOGIN', activebackground='SteelBlue1', activeforeground='white',
                                fg='brown', bg='#F0F8FF', font=('Andalus', 15, 'bold'),
                                command=login)

username_label.place(x=20, y=20)
password_label.place(x=20, y=60)
username_entry.place(x=160, y=20, width=200)
password_entry.place(x=160, y=60, width=200)
btn_login.place(x=160, y=100, width=200)

# Opening JSON file
f = open('id.json')
# returns JSON object as a dictionary
data = json.load(f)
# Closing file
f.close()

root.mainloop()

# %%
# class mainscreen():
#Creating the main window
window = Tk()
window.title("PIANO")
window.configure(bg='#cdc0b0') #set background cho window
window.geometry("700x600")

#frame và label
#frame xám
headingFrame1 = Label(window,bg="#714d28",  width = 72, height = 9)
headingFrame1.place(x=60, y=10)
headingLabel = Label(headingFrame1, text="Piano for Your life! 🎹", fg='#000000', font=('Arial',20,'bold'), width = 30, height = 3)
headingLabel.place(x=30,y=10)

#Button để add thêm sản phẩm
addpiano_btn = Button(window,text="Add a Piano",bg='#8b7e66', fg='white', width=15,height=2, command = addProd)
addpiano_btn['font'] = font.Font( size=12)
addpiano_btn.place(x=100,y = 200)

#Button xóa đàn
delpiano_btn = Button(window,text="Delete a Piano",bg='#8b7e66', fg='white',width=15,height=2)
delpiano_btn['font'] = font.Font( size=12)
delpiano_btn.place(x=400,y= 200)


#Button xem toàn bộ đàn trong kho
fullpiano_btn = Button(window,text="View all Piano",bg='old lace', fg='black',width=28,height=2)
fullpiano_btn['font'] = font.Font( size=18)
fullpiano_btn.place(x=130,y=300)

#Button tạo hóa đơn
bill_btn = Button(window,text="Bill",bg='lavender blush2', fg='black', width=28,height=2)
bill_btn['font'] = font.Font( size=18)
bill_btn.place(x=130,y=450)

#Tính năng add đàn


#Function lấy thông tin chi tiết của đàn đã dc add vào
def addProd(): 
    global PianoName, PianoPrice
    
    #tạo cửa sổ để add sản phẩm
    win = Tk() 
    win.title("Piano Sales Management System")
    win.configure(bg='mint cream')
    win.geometry("700x600")
    #Canvas1 = Canvas(wn)
    #Canvas1.config(bg='LightBlue1')
    #Canvas1.pack(expand=True,fill=BOTH)
    
    headingFrame1 = Frame(win,bg='LightBlue1',bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
    headingLabel = Label(headingFrame1, text="Add a Product", fg='grey19', font=('Courier',15,'bold'))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    labelFrame = Frame(win)
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)

        
    # Product Name
    lable2 = Label(labelFrame,text="Product Name : ", fg='black')
    lable2.place(relx=0.05,rely=0.45, relheight=0.08)
        
    PianoName = Entry(labelFrame)
    PianoName.place(relx=0.3,rely=0.45, relwidth=0.62, relheight=0.08)
        
    # Product Price
    lable3 = Label(labelFrame,text="Product Price : ", fg='black')
    lable3.place(relx=0.05,rely=0.6, relheight=0.08)
        
    PianoPrice = Entry(labelFrame)
    PianoPrice.place(relx=0.3,rely=0.6, relwidth=0.62, relheight=0.08)
           
    #Add Button
    Btn = Button(win,text="ADD",bg='#d1ccc0', fg='black')
    Btn.place(relx=0.28,rely=0.85, relwidth=0.18,relheight=0.08)
    
    Quit= Button(win,text="Quit",bg='#f7f1e3', fg='black', command=win.destroy)
    Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)
    

    win.mainloop()

# %%
win = Tk() 
win.title("PythonGeeks Shop Management System")
win.configure(bg='mint cream')
win.geometry("700x600")
#Canvas1 = Canvas(wn)
#Canvas1.config(bg='LightBlue1')
#Canvas1.pack(expand=True,fill=BOTH)

headingFrame1 = Frame(win,bg='LightBlue1',bd=5)
headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
headingLabel = Label(headingFrame1, text="Add a Product", fg='grey19', font=('Courier',15,'bold'))
headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
labelFrame = Frame(win)
labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)


# Product Name
lable2 = Label(labelFrame,text="Product Name : ", fg='black')
lable2.place(relx=0.05,rely=0.45, relheight=0.08)

PianoName = Entry(labelFrame)
PianoName.place(relx=0.3,rely=0.45, relwidth=0.62, relheight=0.08)

# Product Price
lable3 = Label(labelFrame,text="Product Price : ", fg='black')
lable3.place(relx=0.05,rely=0.6, relheight=0.08)

PianoPrice = Entry(labelFrame)
PianoPrice.place(relx=0.3,rely=0.6, relwidth=0.62, relheight=0.08)
    
#Add Button
Btn = Button(win,text="ADD",bg='#d1ccc0', fg='black')
Btn.place(relx=0.28,rely=0.85, relwidth=0.18,relheight=0.08)

Quit= Button(win,text="Quit",bg='#f7f1e3', fg='black', command=win.destroy)
Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)


win.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\kieumy-case-study\caseSTUDY.ipynb Cell 4 in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> win = Tk()
#       <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> win.title("PythonGeeks Shop Management System")
#       <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> win.configure(bg='mint cream')
#
# NameError: name 'Tk' is not defined

# %% [markdown]
# Treeview all product

# %%
from tkinter import *
from tkinter import ttk
from tkinter.messagebox import showinfo
import json

root = Tk()
root.title('VIEW ALL PIANO')
root.geometry('700x700')



Canvas1 = Canvas(root) 
Canvas1.config(bg="old lace")
Canvas1.pack(expand=True,fill=BOTH)

headingFrame1 = Frame(root,bg='old lace',bd=5)
headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

headingLabel = Label(headingFrame1, text="View Products", fg='black', font = ('Courier',15,'bold'))
headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

# labelFrame = Frame(root)
# labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
# y = 0.25
# define columns
columns = ("Product brand", "Product price", "Date")

tree = ttk.Treeview(root, columns=columns, show='headings')

# define headings
tree.heading("Product brand", text="Product brand")
tree.heading("Product price", text="Product price")
tree.heading("Date", text="Date")


# Opening JSON file
f = open('product.json')
# returns JSON object as a dictionary
data = json.load(f)
# Closing file
f.close()
count=0
for prod in data['piano']:
    tree.insert(parent='', index="end", iid=count, text="", 
                values=[prod["Product brand"], prod["Product price"], prod["Date"]])
    count+=1
# # add data to the treeview
# for prod in data["piano"]:
#     tree.insert('', tk.END, values=[prod["Product brand"], prod["Product price"], prod["Date"]])



tree.place(relx=0.07,rely=0.3)

# add a scrollbar
scrollbar = ttk.Scrollbar(root, orient=VERTICAL, command=tree.yview)
tree.configure(yscroll=scrollbar.set)
scrollbar.place(relx=0.93,rely=0.3,relheight=0.325)

# run the app
root.mainloop()
