# %%
#Import các thư viện cần thiết
import tkinter
from tkinter import *
from tkinter import ttk
from tkinter import font
from tkinter import messagebox
import json

# %%
# LOG in 

from tkinter import *
from tkinter import ttk

root = Tk()
root.title('Piano Sales Management System')
root.geometry('450x200')
root.resizable(False, False)

# Labels and entries for username and password
root.username_label = Label(root, text='Username', font=('Andalus', 15, 'bold'), fg='brown')
root.password_label = Label(root, text='Password', font=('Andalus', 15, 'bold'),fg='brown')

username_entry_var = StringVar()
password_entry_var = StringVar()

root.username_entry = ttk.Entry(root, textvariable=username_entry_var, 
                                font=('Andalus', 15))
root.password_entry = ttk.Entry(root, textvariable=password_entry_var, show='*', 
                                        font=('Andalus', 15))
root.btn_login = Button(root, text='LOGIN', activebackground='SteelBlue1', activeforeground='white',
                                fg='brown', bg='#F0F8FF', font=('Andalus', 15, 'bold'))

root.username_label.place(x=20, y=20)
root.password_label.place(x=20, y=60)
root.username_entry.place(x=160, y=20, width=200)
root.password_entry.place(x=160, y=60, width=200)
root.btn_login.place(x=160, y=100, width=200)

root.mainloop()

# %%
import tkinter
from tkinter import *
from tkinter import ttk
from tkinter import font
from tkinter import messagebox
import json

# Man hinh chính
#Creating the main window
window = Tk()
window.title("PIANO")
window.configure(bg='#cdc0b0') #set background cho window
window.geometry("700x600")

#frame và label
#frame xám
headingFrame1 = Label(window,bg="#714d28",  width = 72, height = 9)
headingFrame1.place(x=60, y=10)
headingLabel = Label(headingFrame1, text="Piano for Your life! 🎹", fg='#000000', font=('Arial',20,'bold'), width = 30, height = 3)
headingLabel.place(x=30,y=10)

#Button để add thêm sản phẩm
addpiano_btn = Button(window,text="Add a Piano",bg='#8b7e66', fg='white', width=15,height=2, 
                      command = addProd)
addpiano_btn['font'] = font.Font( size=12)
addpiano_btn.place(x=100,y = 200)

#Button xóa đàn
delpiano_btn = Button(window,text="Delete a Piano",bg='#cdc0b0', fg='black',width=15,height=2, 
                      command = delProd)
delpiano_btn['font'] = font.Font( size=12)
delpiano_btn.place(x=400,y= 200)


#Button xem toàn bộ đàn trong kho
fullpiano_btn = Button(window,text="View all Piano",bg='old lace', fg='black',width=28,height=2,
                       command=viewProd)
fullpiano_btn['font'] = font.Font( size=18)
fullpiano_btn.place(x=130,y=300)

#Button tạo hóa đơn
bill_btn = Button(window,text="Bill",bg='lavender blush2', fg='black', width=28,height=2)
bill_btn['font'] = font.Font( size=18)
bill_btn.place(x=130,y=410)

Quit= Button(window,text="Quit",bg='#f7f1e3', fg='black', command=window.destroy)
Quit.place(relx=0.39,rely=0.85, relwidth=0.18,relheight=0.08)



window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2240\2645684847.py", line 68, in delete_piano
#     json.dump(file_data, file)
#   File "c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\json\__init__.py", line 180, in dump
#     fp.write(chunk)
# ValueError: I/O operation on closed file.

# %%
dec ={
    "piano": [
        {
            "Product brand": "Yamaha CLP",
            "Product price": 2000,
            "Date": "10/4/2022"
        },
        {
            "Product brand": "Roland FP",
            "Product price": 3000,
            "Date": "10/4/2022"
        },
        {
            "Product brand": "Piano steinway and sons",
            "Product price": 10000,
            "Date": "10/4/2022"
        },
        {
            "Product brand": "123",
            "Product price": "sdf",
            "Date": "sdf"
        },
        {
            "Product brand": "1",
            "Product price": "1",
            "Date": "1"
        }
    ]
}
delete = {
            "Product brand": "Yamaha CLP",
            "Product price": 2000,
            "Date": "10/4/2022"
        }
for i in range(0, len(dec)+1):
    if dec['piano'][i] == delete:
        dec['piano'][i].pop
dec
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\kieumy-case-study\caseSTUDY111.ipynb Cell 4 in <module>
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=29'>30</a> delete = {
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=30'>31</a>             "Product brand": "Yamaha CLP",
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=31'>32</a>             "Product price": 2000,
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=32'>33</a>             "Date": "10/4/2022"
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=33'>34</a>         }
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=34'>35</a> for i in range(0, len(dec["piano"])+1):
# ---> <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=35'>36</a>     if dec['piano'][i] == delete:
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=36'>37</a>         dec['piano'][i].pop
#      <a href='vscode-notebook-cell:/d%3A/kieumy-case-study/caseSTUDY111.ipynb#X14sZmlsZQ%3D%3D?line=37'>38</a> dec
#
# IndexError: list index out of range

# %%
import json
with open('product.json','r+') as file:
    file_data = json.load(file)
file_data['piano'][0]
# Out:
# {'Product brand': 'Yamaha CLP', 'Product price': 2000, 'Date': '10/4/2022'}

# %%
# TÍNH NĂNG XÓA SẢN PHẨM
def delProd(): 
    global PianoName, PianoPrice, date, Canvas1
    
    #tạo cửa sổ để add sản phẩm
    window = tkinter.Tk() 
    window.title("PIANO")
    window.configure(bg='floralwhite') #background chính cho function XÓA
    window.geometry("700x600")
    #Canvas1 = Canvas(wn)
    #Canvas1.config(bg='LightBlue1')
    #Canvas1.pack(expand=True,fill=BOTH)
    
     # vị trí khung vÀ LABEL ADD PIANO
    
    headingFrame1 = Label(window,bg="floralwhite",  width = 72, height = 9)
    headingFrame1.place(x=60, y=10)
    headingLabel = Label(headingFrame1, text="DELETE YOUR PIANO! 🎹", fg='#000000', font=('Arial',20,'bold'), width = 30, height = 3)
    headingLabel.place(x=30,y=10)
    
    # vị trí khung dưới để input ngày, và sản phẩm
    labelFrame = Frame(window)
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
    
      # Getting Date
    lable1 = Label(labelFrame,text="Date : ", fg='black')
    lable1.place(relx=0.05,rely=0.3, relheight=0.08)
        
    date = Entry(labelFrame)
    date.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
        
    # Product Name
    lable2 = Label(labelFrame,text="Piano Name : ", fg='black')
    lable2.place(relx=0.05,rely=0.45, relheight=0.08)
        
    PianoName = Entry(labelFrame)
    PianoName.place(relx=0.3,rely=0.45, relwidth=0.62, relheight=0.08)
        
    # Product Price
    lable3 = Label(labelFrame,text="Piano Price : ", fg='black')
    lable3.place(relx=0.05,rely=0.6, relheight=0.08)
        
    PianoPrice = Entry(labelFrame)
    PianoPrice.place(relx=0.3,rely=0.6, relwidth=0.62, relheight=0.08)
           
    #Add Button
    Btn = Button(window,text="Delete",bg='#d1ccc0', fg='black', command=delete_piano)
    Btn.place(relx=0.28,rely=0.85, relwidth=0.18,relheight=0.08)
    
    Quit= Button(window,text="Quit",bg='#f7f1e3', fg='black', command=window.destroy)
    Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)

def delete_piano():
  global del_item
  del_item = {
                "Product brand":PianoName.get(),
                "Product price":PianoPrice.get(),
                "Date":date.get()
              }
  with open('product.json','r+') as file:
          file_data = json.load(file)
  # test_list = file_data['piano']
  # n=len(test_list)+1
  for i in range(0, len(file_data['piano'])+1):
    if file_data['piano'][i] == del_item:
        file_data['piano'][i].pop
        break
  json.dump(file_data, file)
  file.close()

# %%
# Them san pham
def addProd(): 
    global PianoName, PianoPrice, date, Canvas1
    
    #tạo cửa sổ để add sản phẩm
    window = tkinter.Tk() 
    window.title("PIANO")
    window.configure(bg='#deb887') #background chính cho function ADD
    window.geometry("700x600")
    #Canvas1 = Canvas(wn)
    #Canvas1.config(bg='LightBlue1')
    #Canvas1.pack(expand=True,fill=BOTH)
    
     # vị trí khung vÀ LABEL ADD PIANO
    
    headingFrame1 = Label(window,bg="#deb887",  width = 72, height = 9)
    headingFrame1.place(x=60, y=10)
    headingLabel = Label(headingFrame1, text="ADD YOUR PIANO! 🎹", fg='#000000', font=('Arial',20,'bold'), width = 30, height = 3)
    headingLabel.place(x=30,y=10)
    
    # vị trí khung dưới để input ngày, và sản phẩm
    labelFrame = Frame(window)
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
    
    PianoName_var = StringVar()
    date_var = StringVar()
    PianoPrice_var = StringVar()
      # Getting Date
    lable1 = Label(labelFrame,text="Date : ", fg='black')
    lable1.place(relx=0.05,rely=0.3, relheight=0.08)
        
    date = Entry(labelFrame, textvariable=date_var)
    date.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
        
    # Product Name
    lable2 = Label(labelFrame,text="Piano Name : ", fg='black')
    lable2.place(relx=0.05,rely=0.45, relheight=0.08)
        
    PianoName = Entry(labelFrame, textvariable=PianoName_var)
    PianoName.place(relx=0.3,rely=0.45, relwidth=0.62, relheight=0.08)
        
    # Product Price
    lable3 = Label(labelFrame,text="Piano Price : ", fg='black')
    lable3.place(relx=0.05,rely=0.6, relheight=0.08)
        
    PianoPrice = Entry(labelFrame, textvariable=PianoPrice_var)
    PianoPrice.place(relx=0.3,rely=0.6, relwidth=0.62, relheight=0.08)
           
    #Add Button
    Btn = Button(window,text="ADD",bg='#d1ccc0', fg='black', command=write_json)
    Btn.place(relx=0.28,rely=0.85, relwidth=0.18,relheight=0.08)
    
    Quit= Button(window,text="Quit",bg='#f7f1e3', fg='black', command=window.destroy)
    Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)
    # global new_input
    # new_input = {
    #           "Product brand":PianoName.get(),
    #           "Product price":PianoPrice.get(),
    #           "Date":date.get()
    #         }
            


# new_input = {
#               "Product brand":PianoName.get(),
#               "Product price":PianoPrice.get(),
#               "Date":date.get()
#             }

    
# def save_in_json_file(collection,filename='product.json'):
#      with open(filename, 'w+') as f:
#          json.dump(collection, f, indent=4)

def write_json():
    new_input = {
              "Product brand":PianoName.get(),
              "Product price":PianoPrice.get(),
              "Date":date.get()
            }
    with open('product.json','r+') as file:
          # First we load existing data into a dict.
        file_data = json.load(file)
        # Join new_data with file_data inside emp_details
        file_data['piano'].append(new_input)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file, indent = 4)
        file.close()

# %%
def save_in_json_file(collection,filename='product.json'):
        with open(filename, 'w+') as f:
            json.dump(collection, f, indent=4)

# %%
import json
f = open('product.json')
# returns JSON object as a dictionary
data = json.load(f)


# Closing file
f.close()
data

# %%
#Tinh nang xem san pham
def viewProd():
    window = Tk()
    window.title('VIEW ALL PIANO')
    window.geometry('700x700')

#Add heading
    Canvas1 = Canvas(window) 
    Canvas1.config(bg="old lace")
    Canvas1.pack(expand=True,fill=BOTH)

    headingFrame1 = Frame(window,bg='old lace',bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="View Products", fg='black', font = ('Courier',15,'bold'))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    # labelFrame = Frame(window)
    # labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    # y = 0.25
    # define columns
    columns = ("Product brand", "Product price", "Date")

    tree = ttk.Treeview(window, columns=columns, show='headings')

    # define headings
    tree.heading("Product brand", text="Product brand")
    tree.heading("Product price", text="Product price")
    tree.heading("Date", text="Date")


    # Opening JSON file
    f = open('D:\kieumy-case-study\product.json')
    # returns JSON object as a dictionary
    data = json.load(f)
    # Closing file
    f.close()
    #Add data vao bang
    count=0
    for prod in data['piano']:
        tree.insert(parent='', index="end", iid=count, text="", 
                    values=[prod["Product brand"], prod["Product price"], prod["Date"]])
        count+=1

    tree.place(relx=0.07,rely=0.3)

    # add a scrollbar
    scrollbar = ttk.Scrollbar(window, orient=VERTICAL, command=tree.yview)
    tree.configure(yscroll=scrollbar.set)
    scrollbar.place(relx=0.93,rely=0.3,relheight=0.325)


    #Quit button
    Quit= Button(window,text="Quit",bg='#f7f1e3', fg='black', command=window.destroy)
    Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)
    # run the app
    window.mainloop()

# %% [markdown]
# class xem sản phẩm

# %%
import tkinter 
from tkinter import *
from tkinter import ttk
import json

class viewProd(Tk):
    def __init__(self):
        super().__init__()

        self.title('VIEW ALL PIANO')
        self.geometry('700x700')

        self.tree = self.viewProd()

        #Tinh nang xem san pham
    def viewProd(self):
    #Add heading
        Canvas1 = Canvas(self) 
        Canvas1.config(bg="old lace")
        Canvas1.pack(expand=True,fill=BOTH)

        headingFrame1 = Frame(self,bg='old lace',bd=5)
        headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

        headingLabel = Label(headingFrame1, text="View Products", fg='black', font = ('Courier',15,'bold'))
        headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

        # define columns
        columns = ("Product brand", "Product price", "Date")

        tree = ttk.Treeview(self, columns=columns, show='headings')

        # define headings
        tree.heading("Product brand", text="Product brand")
        tree.heading("Product price", text="Product price")
        tree.heading("Date", text="Date")


        # Opening JSON file
        f = open('D:\kieumy-case-study\product.json')
        # returns JSON object as a dictionary
        data = json.load(f)
        # Closing file
        f.close()
        #Add data vao bang
        count=0
        for prod in data['piano']:
            tree.insert(parent='', index="end", iid=count, text="", 
                        values=[prod["Product brand"], prod["Product price"], prod["Date"]])
            count+=1

        tree.place(relx=0.07,rely=0.3)

        # add a scrollbar
        scrollbar = ttk.Scrollbar(self, orient=VERTICAL, command=tree.yview)
        tree.configure(yscroll=scrollbar.set)
        scrollbar.place(relx=0.93,rely=0.3,relheight=0.325)


        #Quit button
        Quit= Button(self,text="Quit",bg='#f7f1e3', fg='black', command=self.destroy)
        Quit.place(relx=0.53,rely=0.85, relwidth=0.18,relheight=0.08)
        # run the app
        return tree
        

if __name__ == '__main__':
    app = viewProd()
    app.mainloop()

# %%
import tkinter 
from tkinter import *
from tkinter import ttk


class App(Tk):
    def __init__(self):
        super().__init__()

        self.title('Treeview demo')
        self.geometry('620x200')

        self.tree = self.create_tree_widget()

    def create_tree_widget(self):
        columns = ('first_name', 'last_name', 'email')
        tree = ttk.Treeview(self, columns=columns, show='headings')

        # define headings
        tree.heading('first_name', text='First Name')
        tree.heading('last_name', text='Last Name')
        tree.heading('email', text='Email')

        tree.grid(row=0, column=0, sticky=tk.NSEW)

        # adding an item
        tree.insert('', tk.END, values=('John', 'Doe', 'john.doe@email.com'))

        # insert a the end
        tree.insert('', tk.END, values=('Jane', 'Miller', 'jane.miller@email.com'))

        # insert at the beginning
        tree.insert('', 0, values=('Alice', 'Garcia', 'alice.garcia@email.com'))

        return tree


if __name__ == '__main__':
    app = App()
    app.mainloop()
